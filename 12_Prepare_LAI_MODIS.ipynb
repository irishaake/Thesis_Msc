# %% [markdown]
# ## Prepare LAI from MODIS Data

# %% [markdown]
# In this notebook, 8-daily MODIS/Terra & Aqua LAI data from 2000 - 2024 is processed. The following steps are included:
# - Replace fill values with NA
# - Mask pixels based on quality flags
# - Crop to forest area
# - Save datasets for needleleaved and broadleaved forests
# - Save information on quality flags and counts of high quality pixels per year as csv datasets

# %%
# import libraries
import os
import warnings
import xarray as xr
import numpy as np
import pandas as pd

# %%
# set working directory
os.chdir("E:/Master/Thesis/3_Data")
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: E:\Master\Thesis\3_Data

# %%
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
# read MODIS LAI data
lai_full = xr.open_dataset("./Raw/LAI_FAPAR_MODIS/MOD15A2H.061_500m_aid0001.nc", decode_coords="all", decode_times=True)

# %%
lai_full
# Out:
# <xarray.Dataset> Size: 113GB
# Dimensions:       (time: 1139, lat: 1871, lon: 2203)
# Coordinates:
#     crs           int8 1B ...
#   * time          (time) object 9kB 2000-02-18 00:00:00 ... 2024-12-26 00:00:00
#   * lat           (lat) float64 15kB 55.06 55.06 55.05 ... 47.28 47.27 47.27
#   * lon           (lon) float64 18kB 5.865 5.869 5.873 ... 15.03 15.04 15.04
# Data variables:
#     FparExtra_QC  (time, lat, lon) float32 19GB ...
#     FparLai_QC    (time, lat, lon) float32 19GB ...
#     Fpar_500m     (time, lat, lon) float64 38GB ...
#     Lai_500m      (time, lat, lon) float64 38GB ...
# Attributes:
#     title:        MOD15A2H.061 for aid0001
#     Conventions:  CF-1.6
#     institution:  Land Processes Distributed Active Archive Center (LP DAAC)
#     source:       AppEEARS v3.71
#     references:   See README.md
#     history:      See README.md

# %%
# note that FAPAR and LAI are stored in one dataset
# and that all dates from 2000-2024 are stored in one large netCDF dataset
# for now, we only want to consider LAI
lai_full = lai_full.drop_vars("Fpar_500m")

# %%
# convert CFTime index to datetime index
datetimeindex = lai_full.indexes['time'].to_datetimeindex()
lai_full['time'] = datetimeindex
# Out:
# C:\Users\irish\AppData\Local\Temp\ipykernel_31628\3548823652.py:2: FutureWarning: In a future version of xarray to_datetimeindex will default to returning a 'us'-resolution DatetimeIndex instead of a 'ns'-resolution DatetimeIndex. This warning can be silenced by explicitly passing the `time_unit` keyword argument.
#   datetimeindex = lai_full.indexes['time'].to_datetimeindex()

# %%
# rename variables
lai_full = lai_full.rename({"Lai_500m":"LAI", "FparLai_QC":"QA", "FparExtra_QC": "QA_extra"})

# %%
# check crs
lai_full.rio.crs
# Out:
# CRS.from_wkt('GEOGCS["unknown",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]')

# %%
# plot exemplary LAI data of one date to get a first impression
lai_full.LAI.sel(time = "2000-02-18").plot()

# %%
# look at attributes of lai variable
lai_full.LAI.attrs
# Out:
# {'valid_min': np.int16(0),
#  'valid_max': np.int16(100),
#  'scale_factor_err': np.float64(0.0),
#  'add_offset_err': np.float64(0.0),
#  'calibrated_nt': np.int32(21),
#  'long_name': 'MOD15A2H MODIS/Terra Gridded 500M Leaf Area Index LAI (8-day composite)',
#  'units': 'm^2/m^2',
#  'MOD15A2_FILLVALUE_DOC': 'MOD15A2 FILL VALUE LEGEND\n255 = _Fillvalue, assigned when:\n    * the MOD09GA suf. reflectance for channel VIS, NIR was assigned its _Fillvalue, or\n    * land cover pixel itself was assigned _Fillvalus 255 or 254.\n254 = land cover assigned as perennial salt or inland fresh water.\n253 = land cover assigned as barren, sparse vegetation (rock, tundra, desert.)\n252 = land cover assigned as perennial snow, ice.\n251 = land cover assigned as "permanent" wetlands/inundated marshlands.\n250 = land cover assigned as urban/built-up.\n249 = land cover assigned as "unclassified" or not able to determine.\n'}

# %%
# in the dataset, fill values are assigned to pixels where the algorithm could not retrieve a biophysical estimate
# source: https://lpdaac.usgs.gov/documents/926/MOD15_User_Guide_V61.pdf 
# these pixel values should be converted to NA - this will be done in a later step because right now, the full dataset is too large for the operation

# %%
# also plot the quality layers of the same date to get an impression
lai_full.QA.sel(time = "2000-02-18").plot()

# %%
lai_full.QA_extra.sel(time = "2000-02-18").plot()

# %%
# read in quality flag lookup tables that were delivered with data to get information on quality flags
lut = pd.read_csv("./Raw/LAI_FAPAR_MODIS/MOD15A2H-061-FparLai-QC-lookup.csv")
lut
# Out:
#     Value                                            MODLAND Sensor  \
# 0       0  Good quality (main algorithm with or without s...  Terra
# 1       8  Good quality (main algorithm with or without s...  Terra
# 2      16  Good quality (main algorithm with or without s...  Terra
# 3      32  Good quality (main algorithm with or without s...  Terra
# 4      40  Good quality (main algorithm with or without s...  Terra
# 5      48  Good quality (main algorithm with or without s...  Terra
# 6      65   Other Quality (back-up algorithm or fill values)  Terra
# 7      73   Other Quality (back-up algorithm or fill values)  Terra
# 8      81   Other Quality (back-up algorithm or fill values)  Terra
# 9      97   Other Quality (back-up algorithm or fill values)  Terra
# 10    105   Other Quality (back-up algorithm or fill values)  Terra
# 11    113   Other Quality (back-up algorithm or fill values)  Terra
# 12    157   Other Quality (back-up algorithm or fill values)  Terra
#
#                                          DeadDetector  \
# 0   Detectors apparently fine for up to 50% of cha...
# 1   Detectors apparently fine for up to 50% of cha...
# 2   Detectors apparently fine for up to 50% of cha...
# 3   Detectors apparently fine for up to 50% of cha...
# 4   Detectors apparently fine for up to 50% of cha...
# 5   Detectors apparently fine for up to 50% of cha...
# 6   Detectors apparently fine for up to 50% of cha...
# 7   Detectors apparently fine for up to 50% of cha...
# 8   Detectors apparently fine for up to 50% of cha...
# 9   Detectors apparently fine for up to 50% of cha...
# 10  Detectors apparently fine for up to 50% of cha...
# 11  Detectors apparently fine for up to 50% of cha...
# 12  Dead detectors caused >50% adjacent detector r...
#
#                                 CloudState  \
# 0   Significant clouds NOT present (clear)
# 1          Significant clouds WERE present
# 2             Mixed cloud present in pixel
# 3   Significant clouds NOT present (clear)
# 4          Significant clouds WERE present
# 5             Mixed cloud present in pixel
# 6   Significant clouds NOT present (clear)
# 7          Significant clouds WERE present
# 8             Mixed cloud present in pixel
# 9   Significant clouds NOT present (clear)
# 10         Significant clouds WERE present
# 11            Mixed cloud present in pixel
# 12  Cloud state not defined, assumed clear
#
#                                                SCF_QC
# 0   Main (RT) method used, best result possible (n...
# 1   Main (RT) method used, best result possible (n...
# 2   Main (RT) method used, best result possible (n...
# 3   Main (RT) method used with saturation. Good, v...
# 4   Main (RT) method used with saturation. Good, v...
# 5   Main (RT) method used with saturation. Good, v...
# 6   Main (RT) method failed due to bad geometry, e...
# 7   Main (RT) method failed due to bad geometry, e...
# 8   Main (RT) method failed due to bad geometry, e...
# 9   Main (RT) method failed due to problems other ...
# 10  Main (RT) method failed due to problems other ...
# 11  Main (RT) method failed due to problems other ...
# 12  Pixel not produced at all, value couldn't be r...

# %%
lut_extra = pd.read_csv("./Raw/LAI_FAPAR_MODIS/MOD15A2H-061-FparExtra-QC-lookup.csv")
lut_extra
# Out:
#     Value                            LandSea Pass-Thru              Snow_Ice  \
# 0       0             0 LAND AggrQC (3,5) values {001}  No snow/ice detected
# 1       1  1 SHORE AggrQC (3,5) values {000, 010, 100}  No snow/ice detected
# 2       2  2 FRESHWATER AggrQC (3,5) values {011, 101}  No snow/ice detected
# 3       4             0 LAND AggrQC (3,5) values {001}     Snow/ice detected
# 4       5  1 SHORE AggrQC (3,5) values {000, 010, 100}     Snow/ice detected
# ..    ...                                          ...                   ...
# 67    201  1 SHORE AggrQC (3,5) values {000, 010, 100}  No snow/ice detected
# 68    202  2 FRESHWATER AggrQC (3,5) values {011, 101}  No snow/ice detected
# 69    204             0 LAND AggrQC (3,5) values {001}     Snow/ice detected
# 70    205  1 SHORE AggrQC (3,5) values {000, 010, 100}     Snow/ice detected
# 71    206  2 FRESHWATER AggrQC (3,5) values {011, 101}     Snow/ice detected
#
#                                           Aerosol              Cirrus  \
# 0   No or low atmospheric aerosol levels detected  No cirrus detected
# 1   No or low atmospheric aerosol levels detected  No cirrus detected
# 2   No or low atmospheric aerosol levels detected  No cirrus detected
# 3   No or low atmospheric aerosol levels detected  No cirrus detected
# 4   No or low atmospheric aerosol levels detected  No cirrus detected
# ..                                            ...                 ...
# 67        Average or high aerosol levels detected  No cirrus detected
# 68        Average or high aerosol levels detected  No cirrus detected
# 69        Average or high aerosol levels detected  No cirrus detected
# 70        Average or high aerosol levels detected  No cirrus detected
# 71        Average or high aerosol levels detected  No cirrus detected
#
#    Internal_CloudMask              Cloud_Shadow                SCF_Biome_Mask
# 0           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 1           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 2           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 3           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 4           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# ..                ...                       ...                           ...
# 67          No clouds     Cloud shadow detected       Biome in interval <1,4>
# 68          No clouds     Cloud shadow detected       Biome in interval <1,4>
# 69          No clouds     Cloud shadow detected       Biome in interval <1,4>
# 70          No clouds     Cloud shadow detected       Biome in interval <1,4>
# 71          No clouds     Cloud shadow detected       Biome in interval <1,4>
#
# [72 rows x 8 columns]

# %%
# extract all quality flag values that are fit for our purpose and should be kept in the dataset
# sources: https://lpdaac.usgs.gov/documents/926/MOD15_User_Guide_V61.pdf and Pu et al. (2024)

# include good quality based on MODLAND
lut = lut[lut['MODLAND'] == 'Good quality (main algorithm with or without saturation)']

# exclude pixels with clouds
cloudstate = ["Significant clouds NOT present (clear)", "Cloud state not defined, assumed clear"]
lut = lut[lut['CloudState'].isin(cloudstate)]

# include only pixels where main algorithm was used
algorithm = ["Main (RT) method used, best result possible (no saturation)", "Main (RT) method used with saturation. Good, very usable"]
lut = lut[lut['SCF_QC'].isin(algorithm)]

# look at updated table
lut
# Out:
#    Value                                            MODLAND Sensor  \
# 0      0  Good quality (main algorithm with or without s...  Terra
# 3     32  Good quality (main algorithm with or without s...  Terra
#
#                                         DeadDetector  \
# 0  Detectors apparently fine for up to 50% of cha...
# 3  Detectors apparently fine for up to 50% of cha...
#
#                                CloudState  \
# 0  Significant clouds NOT present (clear)
# 3  Significant clouds NOT present (clear)
#
#                                               SCF_QC
# 0  Main (RT) method used, best result possible (n...
# 3  Main (RT) method used with saturation. Good, v...

# %%
# extract all quality flag values that are fit for our purpose and should be kept in the dataset
# sources: https://lpdaac.usgs.gov/documents/926/MOD15_User_Guide_V61.pdf and Pu et al. (2024)

# include pixels with no or low aerosol levels
lut_extra = lut_extra[lut_extra['Aerosol'] == 'No or low atmospheric aerosol levels detected']

# include where cirrus clouds, clouds, or cloud shadow were not detected
lut_extra = lut_extra[lut_extra['Cirrus'] == 'No cirrus detected' ]
lut_extra = lut_extra[lut_extra['Internal_CloudMask'] == 'No clouds' ]
lut_extra = lut_extra[lut_extra['Cloud_Shadow'] == 'No cloud shadow detected' ]

# look at updated table
lut_extra
# Out:
#     Value                            LandSea Pass-Thru              Snow_Ice  \
# 0       0             0 LAND AggrQC (3,5) values {001}  No snow/ice detected
# 1       1  1 SHORE AggrQC (3,5) values {000, 010, 100}  No snow/ice detected
# 2       2  2 FRESHWATER AggrQC (3,5) values {011, 101}  No snow/ice detected
# 3       4             0 LAND AggrQC (3,5) values {001}     Snow/ice detected
# 4       5  1 SHORE AggrQC (3,5) values {000, 010, 100}     Snow/ice detected
# 5       6  2 FRESHWATER AggrQC (3,5) values {011, 101}     Snow/ice detected
# 36    128             0 LAND AggrQC (3,5) values {001}  No snow/ice detected
# 37    129  1 SHORE AggrQC (3,5) values {000, 010, 100}  No snow/ice detected
# 38    130  2 FRESHWATER AggrQC (3,5) values {011, 101}  No snow/ice detected
# 39    132             0 LAND AggrQC (3,5) values {001}     Snow/ice detected
# 40    133  1 SHORE AggrQC (3,5) values {000, 010, 100}     Snow/ice detected
# 41    134  2 FRESHWATER AggrQC (3,5) values {011, 101}     Snow/ice detected
#
#                                           Aerosol              Cirrus  \
# 0   No or low atmospheric aerosol levels detected  No cirrus detected
# 1   No or low atmospheric aerosol levels detected  No cirrus detected
# 2   No or low atmospheric aerosol levels detected  No cirrus detected
# 3   No or low atmospheric aerosol levels detected  No cirrus detected
# 4   No or low atmospheric aerosol levels detected  No cirrus detected
# 5   No or low atmospheric aerosol levels detected  No cirrus detected
# 36  No or low atmospheric aerosol levels detected  No cirrus detected
# 37  No or low atmospheric aerosol levels detected  No cirrus detected
# 38  No or low atmospheric aerosol levels detected  No cirrus detected
# 39  No or low atmospheric aerosol levels detected  No cirrus detected
# 40  No or low atmospheric aerosol levels detected  No cirrus detected
# 41  No or low atmospheric aerosol levels detected  No cirrus detected
#
#    Internal_CloudMask              Cloud_Shadow                SCF_Biome_Mask
# 0           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 1           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 2           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 3           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 4           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 5           No clouds  No cloud shadow detected  Biome outside interval <1,4>
# 36          No clouds  No cloud shadow detected       Biome in interval <1,4>
# 37          No clouds  No cloud shadow detected       Biome in interval <1,4>
# 38          No clouds  No cloud shadow detected       Biome in interval <1,4>
# 39          No clouds  No cloud shadow detected       Biome in interval <1,4>
# 40          No clouds  No cloud shadow detected       Biome in interval <1,4>
# 41          No clouds  No cloud shadow detected       Biome in interval <1,4>

# %%
# extract quality flags that indicate good pixel quality
qa_tokeep = list(lut["Value"])
qa_extra_tokeep = list(lut_extra["Value"])

# %%
# get all dates that are stored in large dataset
dates = list(lai_full.time.values)

# %%
# loop over dates to process each date seperately
# dataset is too large to be processed at once

for d in dates:
    
    # extract data of this date as xarray
    lai = lai_full.sel(time = d)

    # manually get time back as dimension, not just variable
    # time dimension was dropped when selecting
    lai = lai.expand_dims('time')

    # replace fill value with NA
    # valid lai range is 0 to 100, fill value is 249 to 255, according to https://lpdaac.usgs.gov/documents/926/MOD15_User_Guide_V61.pdf
    # but the scale factor of 0.1 is automatically applied to the data, so we convert values larger than or equal to 24.9 to NA
    lai['LAI'] = xr.where((lai['LAI'] < 24.9), lai['LAI'], np.nan)

    # create masks for the lai dataset that only keeps pixels of good quality
    # use quality flags that were just determined
    mask1 = lai["QA"].isin(qa_tokeep).compute()
    mask2 = lai["QA_extra"].isin(qa_extra_tokeep).compute()

    # mask data
    lai_masked_pre = lai.where(mask1, drop = False)
    lai_masked = lai_masked_pre["LAI"].where(mask2, drop = False)

    # load forest area from ESA Landcover data for corresponding year
    # attention: forest data only available for 1992 - 2022 -> choose 2022 for lai data of 2022 - 2024
    year = int(str(d)[0:4])

    if year >= 2022:
        forest_year = 2022
    else: forest_year = year

    forest = xr.open_dataset(f"./Forest_GER/Forest_GER_{forest_year}.nc", 
                            decode_coords = "all", 
                            decode_times= True)

    # set crs for lai data 
    lai_masked.rio.write_crs(4326, inplace = True)

    # set spatial dims again - otherwise resampling raises an error
    lai_masked.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace = True)

    # resample lai dataset to match resolution of forest dataset
    lai_match = lai_masked.rio.reproject_match(forest)

    # rename dimensions - they got renamed while resampling
    lai_match = lai_match.rename({'y':'lat', 'x':'lon'})

    # mask lai with forest data
    # broadleaved forest:
    lai_BL = lai_match.where(forest.lccs_class.sel(time=f"{forest_year}-01-01") == 60, 
                                drop = False)

    # needleleaved forest:
    NL_mask = forest.lccs_class.sel(time=f"{forest_year}-01-01").isin([70, 80]).compute()
    lai_NL = lai_match.where(NL_mask, drop = False)

    # compress data to reduce size
    comp = dict(zlib=True, complevel=4)
    lai_BL.encoding.update(comp)
    lai_NL.encoding.update(comp)

    # save as netCDF4 datasets
    date = lai_match.coords["time"].dt.strftime('%Y-%m-%d').values[0]
    lai_BL.to_netcdf(f"./LAI/8Daily/{year}/LAI_{date}_BL.nc", engine = "netcdf4")
    lai_NL.to_netcdf(f"./LAI/8Daily/{year}/LAI_{date}_NL.nc", engine = "netcdf4")

# %%
# load one processed dataset as example and plot to get an overview
lai_NL = xr.open_dataarray("./LAI/8Daily/2020/LAI_2020-08-20_NL.nc", decode_coords = "all", decode_times= True)
lai_NL
# Out:
# <xarray.DataArray 'LAI' (time: 1, lat: 2952, lon: 3510)> Size: 83MB
# [10361520 values with dtype=float64]
# Coordinates:
#     crs          int8 1B ...
#   * time         (time) datetime64[ns] 8B 2020-08-20
#     spatial_ref  int64 8B ...
#   * lon          (lon) float64 28kB 5.451 5.454 5.457 5.46 ... 15.19 15.2 15.2
#   * lat          (lat) float64 24kB 55.2 55.2 55.19 55.19 ... 47.01 47.0 47.0

# %%
lai_NL.plot()

# %%
# to get more information on pixel quality:
# count quality flag frequencies and pixels of high quality per year
# please note: results will be the same as fapar modis data as they share the same quality flag layers
# but for the sake of completeness, this would be the way to go:

# read in again quality flag lookup tables that were delivered with data
lut = pd.read_csv("./Raw/LAI_FAPAR_MODIS/MOD15A2H-061-FparLai-QC-lookup.csv")
lut_extra = pd.read_csv("./Raw/LAI_FAPAR_MODIS/MOD15A2H-061-FparExtra-QC-lookup.csv")

# %%
# rename columns with quality flags
lut.rename({"Value":'qa_flag'},axis=1, inplace= True)
lut_extra.rename({"Value":'qa_flag'},axis=1, inplace= True)

# %%
# read in tables with quality flag statistics that were also delivered with data
qa_stats = pd.read_csv("./Raw/LAI_FAPAR_MODIS/MOD15A2H-061-FparLai-QC-Statistics-QA.csv")
qa_extra_stats = pd.read_csv("./Raw/LAI_FAPAR_MODIS/MOD15A2H-061-FparExtra-QC-Statistics-QA.csv")

# %%
qa_stats
# Out:
#                             File      aid        Date          0         8  \
# 0     FparLai_QC_2000049_aid0001  aid0001  2000-02-18    90305.0  138096.0
# 1     FparLai_QC_2000057_aid0001  aid0001  2000-02-26  1656241.0  342935.0
# 2     FparLai_QC_2000065_aid0001  aid0001  2000-03-05   881479.0  697924.0
# 3     FparLai_QC_2000073_aid0001  aid0001  2000-03-13  1531618.0  350810.0
# 4     FparLai_QC_2000081_aid0001  aid0001  2000-03-21  1872020.0  130916.0
# ...                          ...      ...         ...        ...       ...
# 1134  FparLai_QC_2024329_aid0001  aid0001  2024-11-24   119721.0     734.0
# 1135  FparLai_QC_2024337_aid0001  aid0001  2024-12-02        NaN       NaN
# 1136  FparLai_QC_2024345_aid0001  aid0001  2024-12-10        NaN       NaN
# 1137  FparLai_QC_2024353_aid0001  aid0001  2024-12-18        NaN       NaN
# 1138  FparLai_QC_2024361_aid0001  aid0001  2024-12-26        NaN       NaN
#
#             16     32     40     48         65         73        81       97  \
# 0      33112.0    4.0   29.0    6.0        NaN        NaN       NaN  34131.0
# 1     399211.0   54.0   81.0   12.0        NaN        NaN       NaN  20568.0
# 2     343175.0   38.0   77.0    6.0        NaN        NaN       NaN  42068.0
# 3     327355.0  280.0  196.0   84.0        NaN        NaN       NaN  41075.0
# 4     379768.0  662.0  207.0  156.0        NaN        NaN       NaN  19258.0
# ...        ...    ...    ...    ...        ...        ...       ...      ...
# 1134    1681.0    2.0    1.0    2.0  1998489.0   186766.0  144503.0      NaN
# 1135       NaN    NaN    NaN    NaN   762915.0  1352806.0  336178.0      NaN
# 1136       NaN    NaN    NaN    NaN   487433.0  1793015.0  171451.0      NaN
# 1137       NaN    NaN    NaN    NaN   934354.0  1101062.0  416483.0      NaN
# 1138       NaN    NaN    NaN    NaN  1863924.0   335248.0  252727.0      NaN
#
#             105      113     157
# 0     2145695.0   9928.0  203685
# 1       28856.0   3358.0  203675
# 2      466372.0  20177.0  203675
# 3      180882.0  19016.0  203675
# 4       42850.0   5479.0  203675
# ...         ...      ...     ...
# 1134        NaN      NaN  203092
# 1135        NaN      NaN  203092
# 1136        NaN      NaN  203092
# 1137        NaN      NaN  203092
# 1138        NaN      NaN  203092
#
# [1139 rows x 16 columns]

# %%
qa_extra_stats
# Out:
#                               File      aid        Date       0      1     2  \
# 0     FparExtra_QC_2000049_aid0001  aid0001  2000-02-18     958    934    77
# 1     FparExtra_QC_2000057_aid0001  aid0001  2000-02-26  457397  57174  3420
# 2     FparExtra_QC_2000065_aid0001  aid0001  2000-03-05  159712  24351  1731
# 3     FparExtra_QC_2000073_aid0001  aid0001  2000-03-13  140854  50139  2810
# 4     FparExtra_QC_2000081_aid0001  aid0001  2000-03-21  292162  69718  3743
# ...                            ...      ...         ...     ...    ...   ...
# 1134  FparExtra_QC_2024329_aid0001  aid0001  2024-11-24  313292  53467  3393
# 1135  FparExtra_QC_2024337_aid0001  aid0001  2024-12-02  119468  13821   529
# 1136  FparExtra_QC_2024345_aid0001  aid0001  2024-12-10   28362   4686   361
# 1137  FparExtra_QC_2024353_aid0001  aid0001  2024-12-18  164855  38625  2145
# 1138  FparExtra_QC_2024361_aid0001  aid0001  2024-12-26  288998  34310  2605
#
#             4       5      6       8  ...    194      196     197   198  \
# 0       149.0    16.0    NaN    2379  ...  145.0    982.0    56.0   NaN
# 1     23428.0  1459.0   20.0  121903  ...  265.0    348.0    27.0   2.0
# 2     19689.0  1474.0    2.0  146324  ...  210.0    642.0    57.0   NaN
# 3     12099.0  1020.0    2.0  306192  ...  254.0    344.0    42.0   2.0
# 4     13137.0  1201.0    7.0  396549  ...  219.0    253.0    27.0   2.0
# ...       ...     ...    ...     ...  ...    ...      ...     ...   ...
# 1134   4935.0   615.0   44.0  240883  ...  405.0    684.0   120.0   5.0
# 1135  13820.0  2314.0   17.0   56693  ...  318.0   7124.0  1507.0  36.0
# 1136  10845.0   778.0    5.0   44049  ...  232.0   4529.0   536.0  12.0
# 1137  23310.0  1893.0  131.0    9689  ...  551.0  15761.0  3314.0  30.0
# 1138  26123.0  1899.0   36.0   88825  ...  633.0  15440.0  1531.0  14.0
#
#          200     201   202    204   205  206
# 0      45006    25.0   NaN   64.0   NaN  NaN
# 1      82529    41.0   NaN   21.0   NaN  NaN
# 2     114962    13.0   NaN  133.0   NaN  NaN
# 3     111343     2.0   NaN   18.0   NaN  NaN
# 4      70560     NaN   NaN    3.0   NaN  NaN
# ...      ...     ...   ...    ...   ...  ...
# 1134   67395  2967.0  32.0  417.0  18.0  NaN
# 1135   50817   569.0   5.0  232.0   2.0  4.0
# 1136   15600   311.0  19.0  198.0   NaN  NaN
# 1137   22465   210.0  27.0  886.0   NaN  NaN
# 1138   25068   574.0  15.0  355.0   1.0  1.0
#
# [1139 rows x 75 columns]

# %%
# drop unneeded columns
qa_stats = qa_stats.drop(["File", "aid"], axis=1)
qa_extra_stats = qa_extra_stats.drop(["File", "aid"], axis=1)

# extract year as new column
qa_stats["Year"] = qa_stats['Date'].astype(str).str[0:4]
qa_extra_stats["Year"] = qa_extra_stats['Date'].astype(str).str[0:4]

# %%
# create empty lists for pixel counts
years = []
pixel_counts = []
high_quality_pixel_counts = []
high_quality_extra_pixel_counts = []

# %%
# loop over each year to get yearly statistics of qa_stats
for year in range(2000, 2025):

    # get all dates from this year and extract them
    qa_stats_yearly = qa_stats[(qa_stats["Year"] == str(year))]

    # drop unneeded columns
    qa_stats_yearly = qa_stats_yearly.drop(["Date", "Year"], axis=1)

    # calculate sum of flag counts of dates in each year to get flag frequencies for this year
    df_qa_freq = pd.DataFrame(qa_stats_yearly.sum())

    # create new column with quality flag
    df_qa_freq["qa_flag"] = df_qa_freq.index

    # reset index
    df_qa_freq.reset_index(drop = True, inplace = True)

    # rename column with counts
    df_qa_freq.rename({0:'qa_flag_freq'},axis=1, inplace= True)

    # convert values to integer
    df_qa_freq = df_qa_freq.astype(int)

    # add information from lookup table to flags
    df_qa_freq = pd.merge(df_qa_freq, lut, on = "qa_flag")

    # save quality flag frequencies as csv
    df_qa_freq.to_csv(f"./Tables/LAI_Quality_Assessment/LAI_QA_Flag_Frequency_{year}.csv")

    # extract all quality flag values that are fit for our purpose and should be kept in the dataset
    df_qa_tokeep = df_qa_freq[(df_qa_freq["qa_flag"].isin(qa_tokeep))]

    # append counts to lists    
    years.append(year)
    pixel_counts.append(sum(df_qa_freq.qa_flag_freq))
    high_quality_pixel_counts.append(sum(df_qa_tokeep.qa_flag_freq))

# %%
# loop over each year to get yearly statistics of qa_extra_stats
for year in range(2000, 2025):

    # get all dates from this year and extract them
    qa_stats_yearly = qa_extra_stats[(qa_extra_stats["Year"] == str(year))]

    # drop unneeded columns
    qa_stats_yearly = qa_stats_yearly.drop(["Date", "Year"], axis=1)

    # calculate sum of flag counts of dates in each year to get flag frequencies for this year
    df_qa_freq = pd.DataFrame(qa_stats_yearly.sum())

    # create new column with quality flag
    df_qa_freq["qa_flag"] = df_qa_freq.index

    # reset index
    df_qa_freq.reset_index(drop = True, inplace = True)

    # rename column with counts
    df_qa_freq.rename({0:'qa_flag_freq'},axis=1, inplace= True)

    # convert values to integer
    df_qa_freq = df_qa_freq.astype(int)

    # add information from lookup table to flags
    df_qa_freq = pd.merge(df_qa_freq, lut_extra, on = "qa_flag")

    # save quality flag frequencies as csv
    df_qa_freq.to_csv(f"./Tables/LAI_Quality_Assessment/LAI_QA_Extra_Flag_Frequency_{year}.csv")

    # extract all quality flag values that are fit for our purpose and should be kept in the dataset
    df_qa_tokeep = df_qa_freq[(df_qa_freq["qa_flag"].isin(qa_extra_tokeep))]

    # append counts to lists    
    high_quality_extra_pixel_counts.append(sum(df_qa_tokeep.qa_flag_freq))

# %%
df_qa_pixel_counts = pd.DataFrame({"Year": years,
                                "Pixels": pixel_counts,
                                "High_Quality_Pixels": high_quality_pixel_counts,
                                "High_Quality_Extra_Pixels": high_quality_extra_pixel_counts})

# %%
df_qa_pixel_counts
# Out:
#     Year     Pixels  High_Quality_Pixels  High_Quality_Extra_Pixels
# 0   2000  103544649             51754697                   38790399
# 1   2001  116819604             53132072                   40262610
# 2   2002  122129586             59441203                   42752948
# 3   2003  122129586             62129279                   53376212
# 4   2004  122129586             55923111                   42472285
# 5   2005  122129586             61489059                   53815029
# 6   2006  122129586             54973943                   46036219
# 7   2007  122129586             61861066                   46481130
# 8   2008  122129586             59399323                   47775363
# 9   2009  122129586             57033906                   46123363
# 10  2010  122129586             53184442                   45928008
# 11  2011  122129586             65438801                   51268972
# 12  2012  122129586             56720999                   45528343
# 13  2013  122129586             52851185                   43907229
# 14  2014  122129586             62162388                   43042935
# 15  2015  122129586             60807252                   46502444
# 16  2016  119474595             57532923                   47721675
# 17  2017  122129586             58027823                   45215491
# 18  2018  122129586             66567751                   54498582
# 19  2019  122129586             63157159                   49272040
# 20  2020  122129586             64816718                   50198501
# 21  2021  122129586             58189636                   44749212
# 22  2022  119474595             61623928                   53375690
# 23  2023  122129586             59254922                   47078694
# 24  2024  122129586             58204238                   47315673

# %%
# save pixel counts as csv
df_qa_pixel_counts.to_csv("./Tables/LAI_Quality_Assessment/LAI_QA_Pixel_Counts_2000-2024.csv")
