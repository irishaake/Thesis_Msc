# %% [markdown]
# ## ESA Landcover

# %% [markdown]
# In this notebook, ESA Landcover datasets from 1992 to 2022 are processed. The following steps are included:
# - Crop data for each year to research area (Germany)
# - Select pixels that show needleleaved, broadleaved and mixed forest and save to new datasets
# - Count pixels of each forest type per year
# - Calculate forest area per year
# - Plot evolution of forest types across years

# %%
# import libraries
import os
import xarray as xr
import rioxarray as rioxr
import geopandas as gpd
import rasterio
import odc.stac

# %%
# set working directory
os.chdir("E:/Master/Thesis/3_Data")
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: E:\Master\Thesis\3_Data

# %%
# load landcover dataset of one year as example
lc_1992 = xr.open_dataset("./Raw/LC_ESA/ESACCI-LC-L4-LCCS-Map-300m-P1Y-1992-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc", 
                     decode_coords="all", 
                     decode_times=True)

# %%
# look at dataset
lc_1992
# Out:
# <xarray.Dataset> Size: 124MB
# Dimensions:              (time: 1, lat: 2952, lon: 3510, bounds: 2)
# Coordinates:
#     lat_bounds           (lat, bounds) float64 47kB ...
#     lon_bounds           (lon, bounds) float64 56kB ...
#     time_bounds          (time, bounds) datetime64[ns] 16B ...
#   * lat                  (lat) float64 24kB 55.2 55.2 55.19 ... 47.01 47.0 47.0
#   * lon                  (lon) float64 28kB 5.451 5.454 5.457 ... 15.2 15.2
#   * time                 (time) datetime64[ns] 8B 1992-01-01
# Dimensions without coordinates: bounds
# Data variables:
#     lccs_class           (time, lat, lon) uint8 10MB ...
#     processed_flag       (time, lat, lon) float32 41MB ...
#     current_pixel_state  (time, lat, lon) float32 41MB ...
#     observation_count    (time, lat, lon) uint16 21MB ...
#     change_count         (time, lat, lon) uint8 10MB ...
#     crs                  int32 4B ...
# Attributes: (12/38)
#     id:                         ESACCI-LC-L4-LCCS-Map-300m-P1Y-1992-v2.0.7cds
#     title:                      Land Cover Map of ESA CCI brokered by CDS
#     summary:                    This dataset characterizes the land cover of ...
#     type:                       ESACCI-LC-L4-LCCS-Map-300m-P1Y
#     project:                    Climate Change Initiative - European Space Ag...
#     references:                 http://www.esa-landcover-cci.org/
#     ...                         ...
#     geospatial_lon_max:         180
#     spatial_resolution:         300m
#     geospatial_lat_units:       degrees_north
#     geospatial_lat_resolution:  0.002778
#     geospatial_lon_units:       degrees_east
#     geospatial_lon_resolution:  0.002778

# %%
# plot dataset to get a first impression
lc_1992.lccs_class.plot()

# %%
# check crs
lc_1992.rio.crs

# %%
# the crs has not been defined - define it manually
lc_1992.rio.write_crs(4326, inplace=True)
# Out:
# <xarray.Dataset> Size: 124MB
# Dimensions:              (time: 1, lat: 2952, lon: 3510, bounds: 2)
# Coordinates:
#     lat_bounds           (lat, bounds) float64 47kB ...
#     lon_bounds           (lon, bounds) float64 56kB ...
#     time_bounds          (time, bounds) datetime64[ns] 16B ...
#   * lat                  (lat) float64 24kB 55.2 55.2 55.19 ... 47.01 47.0 47.0
#   * lon                  (lon) float64 28kB 5.451 5.454 5.457 ... 15.2 15.2
#   * time                 (time) datetime64[ns] 8B 1992-01-01
#     spatial_ref          int64 8B 0
# Dimensions without coordinates: bounds
# Data variables:
#     lccs_class           (time, lat, lon) uint8 10MB ...
#     processed_flag       (time, lat, lon) float32 41MB ...
#     current_pixel_state  (time, lat, lon) float32 41MB ...
#     observation_count    (time, lat, lon) uint16 21MB ...
#     change_count         (time, lat, lon) uint8 10MB ...
#     crs                  int32 4B ...
# Attributes: (12/38)
#     id:                         ESACCI-LC-L4-LCCS-Map-300m-P1Y-1992-v2.0.7cds
#     title:                      Land Cover Map of ESA CCI brokered by CDS
#     summary:                    This dataset characterizes the land cover of ...
#     type:                       ESACCI-LC-L4-LCCS-Map-300m-P1Y
#     project:                    Climate Change Initiative - European Space Ag...
#     references:                 http://www.esa-landcover-cci.org/
#     ...                         ...
#     geospatial_lon_max:         180
#     spatial_resolution:         300m
#     geospatial_lat_units:       degrees_north
#     geospatial_lat_resolution:  0.002778
#     geospatial_lon_units:       degrees_east
#     geospatial_lon_resolution:  0.002778

# %%
# check crs again
lc_1992.rio.crs
# Out:
# CRS.from_wkt('GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]')

# %%
# load Germany shapefile 
ger = gpd.read_file("./GER.shp")
# Out:
# c:\Users\irish\miniconda3\envs\Thesis_Msc\Lib\site-packages\pyogrio\core.py:35: RuntimeWarning: Could not detect GDAL data files.  Set GDAL_DATA environment variable to the correct path.
#   _init_gdal_data()
# c:\Users\irish\miniconda3\envs\Thesis_Msc\Lib\site-packages\pyogrio\core.py:36: RuntimeWarning: Could not detect PROJ data files.  Set PROJ_LIB environment variable to the correct path.
#   _init_proj_data()

# %%
# look at shapefile
ger.plot()
# Out:
# <Axes: >

# %%
# check if crs matches landcover data
ger.crs
# Out:
# <Geographic 2D CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84" ...>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (Degree)
# - lat[north]: Latitude (Degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# create mask of research area using the dimensions of the exemplary landcover data
ger_mask = rasterio.features.geometry_mask(ger.geometry, 
                                               out_shape=lc_1992.odc.geobox.shape,
                                               transform=lc_1992.odc.geobox.affine,
                                               all_touched=False,
                                               invert=False)

# %%
ger_mask = xr.DataArray(ger_mask, dims=("lat", "lon"))

# %%
# create loop to process ESA Landcover data for each year
for year in range(1992, 2023):

    # open netCDF dataset of corresponding year
    directory = "./Raw/LC_ESA/"
    for file in os.listdir(directory):
        if str(year) in file and file.endswith(".nc"):
            print(f"File found for {year}: {file}")
            lc = xr.open_dataset(os.path.join(directory, file), decode_coords = "all", decode_times = True)

    # define crs
    lc.rio.write_crs(4326, inplace = True)

    # apply mask of research area to landcover dataset 
    lc_ger = lc.where(~ger_mask)

    # create mask to only select forest  from lccs_class
    # 50 (tree cover, broadleaved, evergreen)
    # 60 (tree cover, broadleaved, deciduous)
    # 70 (tree cover, needleleaved, evergreen)
    # 80 (tree cover, needleleaved, deciduous)
    # 90 (tree cover, mixed leaf)
    forest = lc_ger['lccs_class'].isin([50, 60, 70, 80, 90]).compute()

    # apply mask to lc data
    # only keep variable "lccs_class" to reduce data size
    lc_forest = lc_ger["lccs_class"].where(forest, drop=False)

    # compress data to reduce size
    comp = dict(zlib=True, complevel=4)
    lc_forest.encoding.update(comp)

    # save as netcdf data
    filename = f"Forest_GER_{year}.nc"
    lc_forest.to_netcdf(f"./Forest_GER/{filename}")

    # print status
    print(f"File for year {year} processed.")
# Out:
# File found for 1992: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1992-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1992 processed.
# File found for 1993: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1993-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1993 processed.
# File found for 1994: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1994-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1994 processed.
# File found for 1995: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1995-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1995 processed.
# File found for 1996: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1996-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1996 processed.
# File found for 1997: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1997-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1997 processed.
# File found for 1998: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1998-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1998 processed.
# File found for 1999: ESACCI-LC-L4-LCCS-Map-300m-P1Y-1999-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 1999 processed.
# File found for 2000: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2000-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2000 processed.
# File found for 2001: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2001-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2001 processed.
# File found for 2002: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2002-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2002 processed.
# File found for 2003: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2003-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2003 processed.
# File found for 2004: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2004-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2004 processed.
# File found for 2005: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2005-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2005 processed.
# File found for 2006: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2006-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2006 processed.
# File found for 2007: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2007-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2007 processed.
# File found for 2008: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2008-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2008 processed.
# File found for 2009: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2009-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2009 processed.
# File found for 2010: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2010-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2010 processed.
# File found for 2011: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2011-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2011 processed.
# File found for 2012: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2012-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2012 processed.
# File found for 2013: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2013-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2013 processed.
# File found for 2014: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2014-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2014 processed.
# File found for 2015: ESACCI-LC-L4-LCCS-Map-300m-P1Y-2015-v2.0.7cds.area-subset.55.2.15.2.47.5.45.nc
# File for year 2015 processed.
# File found for 2016: C3S-LC-L4-LCCS-Map-300m-P1Y-2016-v2.1.1.area-subset.55.2.15.2.47.5.45.nc
# File for year 2016 processed.
# File found for 2017: C3S-LC-L4-LCCS-Map-300m-P1Y-2017-v2.1.1.area-subset.55.2.15.2.47.5.45.nc
# File for year 2017 processed.
# File found for 2018: C3S-LC-L4-LCCS-Map-300m-P1Y-2018-v2.1.1.area-subset.55.2.15.2.47.5.45.nc
# File for year 2018 processed.
# File found for 2019: C3S-LC-L4-LCCS-Map-300m-P1Y-2019-v2.1.1.area-subset.55.2.15.2.47.5.45.nc
# File for year 2019 processed.
# File found for 2020: C3S-LC-L4-LCCS-Map-300m-P1Y-2020-v2.1.1.area-subset.55.2.15.2.47.5.45.nc
# File for year 2020 processed.
# File found for 2021: C3S-LC-L4-LCCS-Map-300m-P1Y-2021-v2.1.1.area-subset.55.2.15.2.47.5.45.nc
# File for year 2021 processed.
# File found for 2022: C3S-LC-L4-LCCS-Map-300m-P1Y-2022-v2.1.1.area-subset.55.2.15.2.47.5.45.nc
# File for year 2022 processed.

# %%
# load one processed dataset as example and plot to get an overview
forest_1992 = xr.open_dataarray("./Forest_GER/Forest_GER_1992.nc", decode_coords = "all", decode_times= True)
forest_1992
# Out:
# C:\Users\irish\AppData\Local\Temp\ipykernel_15116\139415199.py:2: UserWarning: Variable(s) referenced in bounds not in variables: ['lat_bounds']
#   forest_1992 = xr.open_dataarray("./Forest_GER/Forest_GER_1992.nc", decode_coords = "all", decode_times= True)
# C:\Users\irish\AppData\Local\Temp\ipykernel_15116\139415199.py:2: UserWarning: Variable(s) referenced in bounds not in variables: ['lon_bounds']
#   forest_1992 = xr.open_dataarray("./Forest_GER/Forest_GER_1992.nc", decode_coords = "all", decode_times= True)
# C:\Users\irish\AppData\Local\Temp\ipykernel_15116\139415199.py:2: UserWarning: Variable(s) referenced in bounds not in variables: ['time_bounds']
#   forest_1992 = xr.open_dataarray("./Forest_GER/Forest_GER_1992.nc", decode_coords = "all", decode_times= True)
# <xarray.DataArray 'lccs_class' (time: 1, lat: 2952, lon: 3510)> Size: 41MB
# [10361520 values with dtype=float32]
# Coordinates:
#   * lat          (lat) float64 24kB 55.2 55.2 55.19 55.19 ... 47.01 47.0 47.0
#   * lon          (lon) float64 28kB 5.451 5.454 5.457 5.46 ... 15.19 15.2 15.2
#   * time         (time) datetime64[ns] 8B 1992-01-01
#     spatial_ref  int64 8B ...
# Attributes:
#     standard_name:        land_cover_lccs
#     flag_colors:          #ffff64 #ffff64 #ffff00 #aaf0f0 #dcf064 #c8c864 #00...
#     long_name:            Land cover class defined in LCCS
#     valid_min:            1
#     valid_max:            220
#     ancillary_variables:  processed_flag current_pixel_state observation_coun...
#     flag_meanings:        no_data cropland_rainfed cropland_rainfed_herbaceou...
#     flag_values:          [  0  10  11  12  20  30  40  50  60  61  62  70  7...

# %%
forest_1992.plot()
